# %%
# !nvidia-smi
# Out:
# Sun Nov  2 02:39:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.2 MB/s eta 0:00:00
# ...

# %%
# !yolo
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
#     Arguments received: ['yolo']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['segment', 'classify', 'detect', 'pose', 'obb']
#                 MODE (required) is one of ['export', 'val', 'benchmark', 'train', 'predict', 'track']
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
# ...

# %%
# !unzip "/content/egg detection label.v2-egg-yolov8-v2.yolov8.zip" -d "/content/egg-detection-yolov8"
# Out:
# Archive:  /content/egg detection label.v2-egg-yolov8-v2.yolov8.zip
#   inflating: /content/egg-detection-yolov8/README.dataset.txt
#   inflating: /content/egg-detection-yolov8/README.roboflow.txt
#   inflating: /content/egg-detection-yolov8/data.yaml
#    creating: /content/egg-detection-yolov8/test/
#    creating: /content/egg-detection-yolov8/test/images/
#  extracting: /content/egg-detection-yolov8/test/images/damaged_114_jpg.rf.48cee7a5eee63a1b6fecee34be365009.jpg
#  extracting: /content/egg-detection-yolov8/test/images/damaged_125_jpg.rf.b71eadd26db1d4f30d39126800891038.jpg
#  extracting: /content/egg-detection-yolov8/test/images/damaged_127_jpg.rf.523db071043e21bcc67f9d92cade572f.jpg
#  extracting: /content/egg-detection-yolov8/test/images/damaged_132_jpg.rf.dca0bfc580578309641033b2e44cab88.jpg
#  extracting: /content/egg-detection-yolov8/test/images/damaged_134_jpg.rf.fbf0b91abe90206141f848055b51dc94.jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='/content/egg-detection-yolov8/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='egg-yolov8n'
)
# Out:
# ...
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Monitor training

# %%
from IPython.display import Image

Image(filename='runs/detect/egg-yolov8n/results.png')

# %% [markdown]
# # Test trained model

# %%
egg_model.predict(
    source='/content/egg-detection-yolov8/test/images',
    save=True
)
# Out:
# image 1/103 /content/egg-detection-yolov8/test/images/damaged_114_jpg.rf.48cee7a5eee63a1b6fecee34be365009.jpg: 480x640 1 Damage, 39.5ms
# image 2/103 /content/egg-detection-yolov8/test/images/damaged_125_jpg.rf.b71eadd26db1d4f30d39126800891038.jpg: 640x480 4 Damages, 6.6ms
# image 3/103 /content/egg-detection-yolov8/test/images/damaged_127_jpg.rf.523db071043e21bcc67f9d92cade572f.jpg: 640x480 1 Damage, 5.9ms
# image 4/103 /content/egg-detection-yolov8/test/images/damaged_132_jpg.rf.dca0bfc580578309641033b2e44cab88.jpg: 640x480 1 Damage, 5.9ms
# image 5/103 /content/egg-detection-yolov8/test/images/damaged_134_jpg.rf.fbf0b91abe90206141f848055b51dc94.jpg: 640x480 3 Damages, 5.9ms
# image 6/103 /content/egg-detection-yolov8/test/images/damaged_136_jpg.rf.b9dac2bbf5b2286552f4690a6faaa9b1.jpg: 480x640 2 Damages, 14.8ms
# image 7/103 /content/egg-detection-yolov8/test/images/damaged_137_jpg.rf.b70ad6d94fff79fbaed9dcc4cb3d4e6f.jpg: 480x640 2 Damages, 10.2ms
# ...

# %%
metrics = egg_model.val()
print("mAP50:", metrics.box.map50)
print("mAP50-95:", metrics.box.map)
print("Precision:", metrics.box.mp)
print("Recall:", metrics.box.mr)
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1911.2±593.3 MB/s, size: 140.7 KB)
# val: Scanning /content/egg-detection-yolov8/valid/labels.cache... 126 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 126/126 261.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.0it/s 4.1s
#                    all        126        150      0.808      0.752      0.764      0.454
#                 Damage         94        112      0.847      0.768      0.831      0.491
#              NotDamage         32         38      0.769      0.737      0.697      0.417
# Speed: 6.6ms preprocess, 4.6ms inference, 0.0ms loss, 4.4ms postprocess per image
# Results saved to /content/runs/detect/val2
# mAP50: 0.7640597404736448
# mAP50-95: 0.45429732539258144
# Precision: 0.8080821972478479
# Recall: 0.7523496240601504
